# %% [markdown]
# ### Configuration of the environment and import of libraries

# %%
import sys
import os
import json

# Navigate up two directories to reach 'backend'
backend_path = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))
sys.path.append(backend_path)

# Now you can import modules from the 'backend' directory
from backend.crud.crud_knowledge_base import crud_knowledge_base
from sqlalchemy.orm import Session  # type: ignore
from sqlalchemy import create_engine  # type: ignore
from backend.core.config import settings

# %%
engine = create_engine(
    f"postgresql://{settings.POSTGRES_USER}:{settings.POSTGRES_PASSWORD}@{settings.POSTGRES_SERVER}:{settings.POSTGRES_PORT}/{settings.POSTGRES_DB}"
)

# %% [markdown]
# ### Fetch shoes from database

# %%
shoes_kb = crud_knowledge_base.get_default_kn_chatbot(db=Session(engine), limit=25)
for shoe in shoes_kb:

    print(shoe.__dict__)
# Out:
# {'_shoe_id': UUID('b9e6c987-43b1-46cd-8fd1-715e03d10bca'), '_shoe_name': 'Nike Air Max 90 Essential', '_brand_name': 'Nike', '_size_number': 43, '_color_name': 'Grey', '_discounted_price': 1600000.0, '_promotion_name': 'Mùa Hè Sale cùng Sole Mate AI', '_promotion_start_date': '01-06-2024', '_promotion_end_date': '31-08-2024', '_promotion_discount_percent': 20}
# {'_shoe_id': UUID('8cb29b0f-279e-485b-ac8b-750cb0543bd2'), '_shoe_name': 'Nike Air Max 90 Essential', '_brand_name': 'Nike', '_size_number': 43, '_color_name': 'Black', '_discounted_price': 1600000.0, '_promotion_name': 'Mùa Hè Sale cùng Sole Mate AI', '_promotion_start_date': '01-06-2024', '_promotion_end_date': '31-08-2024', '_promotion_discount_percent': 20}
# {'_shoe_id': UUID('7645241c-dfef-4847-8fb8-d046ae3ed505'), '_shoe_name': 'Nike Air Max 90 Essential', '_brand_name': 'Nike', '_size_number': 43, '_color_name': 'Red', '_discounted_price': 1600000.0, '_promotion_name': 'Mùa Hè Sale cùng Sole Mate AI', '_promotion_start_date': '01-06-2024', '_promotion_end_date': '31-08-2024', '_promotion_discount_percent': 20}
# {'_shoe_id': UUID('74006003-0f8d-4b4b-9cd9-c56c72921a82'), '_shoe_name': 'Nike Air Max 90 Essential', '_brand_name': 'Nike', '_size_number': 42, '_color_name': 'Yellow', '_discounted_price': 1600000.0, '_promotion_name': 'Mùa Hè Sale cùng Sole Mate AI', '_promotion_start_date': '01-06-2024', '_promotion_end_date': '31-08-2024', '_promotion_discount_percent': 20}
# {'_shoe_id': UUID('4da3c293-578d-4f8f-9d8e-142ebbe056e1'), '_shoe_name': 'Nike Air Max 90 Essential', '_brand_name': 'Nike', '_size_number': 42, '_color_name': 'Blue', '_discounted_price': 1600000.0, '_promotion_name': 'Mùa Hè Sale cùng Sole Mate AI', '_promotion_start_date': '01-06-2024', '_promotion_end_date': '31-08-2024', '_promotion_discount_percent': 20}
# {'_shoe_id': UUID('4720565b-6c27-43da-808d-2c4f87b763f4'), '_shoe_name': 'Nike Air Max 90 Essential', '_brand_name': 'Nike', '_size_number': 43, '_color_name': 'Orange', '_discounted_price': 1600000.0, '_promotion_name': 'Mùa Hè Sale cùng Sole Mate AI', '_promotion_start_date': '01-06-2024', '_promotion_end_date': '31-08-2024', '_promotion_discount_percent': 20}
# {'_shoe_id': UUID('37f3f341-664f-4baa-a5fe-347db8b59c4f'), '_shoe_name': 'Nike Air Max 90 Essential', '_brand_name': 'Nike', '_size_number': 43, '_color_name': 'Yellow', '_discounted_price': 1600000.0, '_promotion_name': 'Mùa Hè Sale cùng Sole Mate AI', '_promotion_start_date': '01-06-2024', '_promotion_end_date': '31-08-2024', '_promotion_discount_percent': 20}
# {'_shoe_id': UUID('292af1e2-2a3d-4f7a-92a3-01931df3fd7f'), '_shoe_name': 'Nike Air Max 90 Essential', '_brand_name': 'Nike', '_size_number': 43, '_color_name': 'Blue', '_discounted_price': 1600000.0, '_promotion_name': 'Mùa Hè Sale cùng Sole Mate AI', '_promotion_start_date': '01-06-2024', '_promotion_end_date': '31-08-2024', '_promotion_discount_percent': 20}
# {'_shoe_id': UUID('1876684a-9b04-4c63-8ade-3b4291a42fc7'), '_shoe_name': 'Nike Air Max 90 Essential', '_brand_name': 'Nike', '_size_number': 42, '_color_name': 'Light Blue', '_discounted_price': 1600000.0, '_promotion_name': 'Mùa Hè Sale cùng Sole Mate AI', '_promotion_start_date': '01-06-2024', '_promotion_end_date': '31-08-2024', '_promotion_discount_percent': 20}
# {'_shoe_id': UUID('039414bd-4df4-4b6e-a701-b3f82ba93090'), '_shoe_name': 'Nike Air Max 90 Essential', '_brand_name': 'Nike', '_size_number': 43, '_color_name': 'Light Blue', '_discounted_price': 1600000.0, '_promotion_name': 'Mùa Hè Sale cùng Sole Mate AI', '_promotion_start_date': '01-06-2024', '_promotion_end_date': '31-08-2024', '_promotion_discount_percent': 20}
# {'_shoe_id': UUID('f7646b3a-8a4e-49fe-9bd3-3f1f27f072c5'), '_shoe_name': 'Reebok Classic', '_brand_name': 'Reebok', '_size_number': 43, '_color_name': 'Red', '_discounted_price': 1600000.0, '_promotion_name': 'Mùa Hè Sale cùng Sole Mate AI', '_promotion_start_date': '01-06-2024', '_promotion_end_date': '31-08-2024', '_promotion_discount_percent': 20}
# {'_shoe_id': UUID('f6f1ecef-7180-4db3-8904-6c41689c9b1e'), '_shoe_name': 'Reebok Classic', '_brand_name': 'Reebok', '_size_number': 43, '_color_name': 'Grey', '_discounted_price': 1600000.0, '_promotion_name': 'Mùa Hè Sale cùng Sole Mate AI', '_promotion_start_date': '01-06-2024', '_promotion_end_date': '31-08-2024', '_promotion_discount_percent': 20}
# {'_shoe_id': UUID('bf2855e0-bf39-44b8-bd80-7549a1136e8c'), '_shoe_name': 'Reebok Classic', '_brand_name': 'Reebok', '_size_number': 43, '_color_name': 'Black', '_discounted_price': 1600000.0, '_promotion_name': 'Mùa Hè Sale cùng Sole Mate AI', '_promotion_start_date': '01-06-2024', '_promotion_end_date': '31-08-2024', '_promotion_discount_percent': 20}
# {'_shoe_id': UUID('628903b9-8edf-4c87-8e6c-5e06d72f7a71'), '_shoe_name': 'Reebok Classic', '_brand_name': 'Reebok', '_size_number': 43, '_color_name': 'Yellow', '_discounted_price': 1600000.0, '_promotion_name': 'Mùa Hè Sale cùng Sole Mate AI', '_promotion_start_date': '01-06-2024', '_promotion_end_date': '31-08-2024', '_promotion_discount_percent': 20}
# {'_shoe_id': UUID('37f7a02f-695b-4a31-976a-4dbbc6bf425f'), '_shoe_name': 'Reebok Classic', '_brand_name': 'Reebok', '_size_number': 43, '_color_name': 'Blue', '_discounted_price': 1600000.0, '_promotion_name': 'Mùa Hè Sale cùng Sole Mate AI', '_promotion_start_date': '01-06-2024', '_promotion_end_date': '31-08-2024', '_promotion_discount_percent': 20}
# {'_shoe_id': UUID('118c78d8-a3cb-43a6-852a-31a5c7bd0325'), '_shoe_name': 'Reebok Classic', '_brand_name': 'Reebok', '_size_number': 42, '_color_name': 'Light Blue', '_discounted_price': 1600000.0, '_promotion_name': 'Mùa Hè Sale cùng Sole Mate AI', '_promotion_start_date': '01-06-2024', '_promotion_end_date': '31-08-2024', '_promotion_discount_percent': 20}
# {'_shoe_id': UUID('0c74f3b5-92ec-4bc8-92ac-e5f6d00bbeb1'), '_shoe_name': 'Reebok Classic', '_brand_name': 'Reebok', '_size_number': 42, '_color_name': 'Yellow', '_discounted_price': 1600000.0, '_promotion_name': 'Mùa Hè Sale cùng Sole Mate AI', '_promotion_start_date': '01-06-2024', '_promotion_end_date': '31-08-2024', '_promotion_discount_percent': 20}
# {'_shoe_id': UUID('064b83c5-72f8-406e-bdd3-371e93faa436'), '_shoe_name': 'Reebok Classic', '_brand_name': 'Reebok', '_size_number': 42, '_color_name': 'Blue', '_discounted_price': 1600000.0, '_promotion_name': 'Mùa Hè Sale cùng Sole Mate AI', '_promotion_start_date': '01-06-2024', '_promotion_end_date': '31-08-2024', '_promotion_discount_percent': 20}
# {'_shoe_id': UUID('05e61f8d-ca28-4f94-9cae-4183848e9222'), '_shoe_name': 'Reebok Classic', '_brand_name': 'Reebok', '_size_number': 43, '_color_name': 'Light Blue', '_discounted_price': 1600000.0, '_promotion_name': 'Mùa Hè Sale cùng Sole Mate AI', '_promotion_start_date': '01-06-2024', '_promotion_end_date': '31-08-2024', '_promotion_discount_percent': 20}
# {'_shoe_id': UUID('01cd4636-1009-4e9b-b731-f05764dd4374'), '_shoe_name': 'Reebok Classic', '_brand_name': 'Reebok', '_size_number': 43, '_color_name': 'Orange', '_discounted_price': 1600000.0, '_promotion_name': 'Mùa Hè Sale cùng Sole Mate AI', '_promotion_start_date': '01-06-2024', '_promotion_end_date': '31-08-2024', '_promotion_discount_percent': 20}
# {'_shoe_id': UUID('f7985791-a7be-481c-b43b-20b9964dc492'), '_shoe_name': 'Puma Suede Classic+', '_brand_name': 'Puma', '_size_number': 42, '_color_name': 'Blue', '_discounted_price': 1800000.0, '_promotion_name': 'Quay Trở Lại Trường Học', '_promotion_start_date': '01-09-2024', '_promotion_end_date': '30-09-2024', '_promotion_discount_percent': 10}
# {'_shoe_id': UUID('bdd1e99d-1c36-4a84-8158-43b56a6f6592'), '_shoe_name': 'Puma Suede Classic+', '_brand_name': 'Puma', '_size_number': 43, '_color_name': 'Light Blue', '_discounted_price': 1800000.0, '_promotion_name': 'Quay Trở Lại Trường Học', '_promotion_start_date': '01-09-2024', '_promotion_end_date': '30-09-2024', '_promotion_discount_percent': 10}
# {'_shoe_id': UUID('69fc67db-d911-4e60-bce6-074c51c6423a'), '_shoe_name': 'Puma Suede Classic+', '_brand_name': 'Puma', '_size_number': 43, '_color_name': 'Black', '_discounted_price': 1800000.0, '_promotion_name': 'Quay Trở Lại Trường Học', '_promotion_start_date': '01-09-2024', '_promotion_end_date': '30-09-2024', '_promotion_discount_percent': 10}
# {'_shoe_id': UUID('69c6e062-ba67-44e9-9631-d01ea0d9b016'), '_shoe_name': 'Puma Suede Classic+', '_brand_name': 'Puma', '_size_number': 42, '_color_name': 'Light Blue', '_discounted_price': 1800000.0, '_promotion_name': 'Quay Trở Lại Trường Học', '_promotion_start_date': '01-09-2024', '_promotion_end_date': '30-09-2024', '_promotion_discount_percent': 10}
# {'_shoe_id': UUID('5bd99d34-4785-4b74-8f22-4985582ea5c2'), '_shoe_name': 'Puma Suede Classic+', '_brand_name': 'Puma', '_size_number': 43, '_color_name': 'Yellow', '_discounted_price': 1800000.0, '_promotion_name': 'Quay Trở Lại Trường Học', '_promotion_start_date': '01-09-2024', '_promotion_end_date': '30-09-2024', '_promotion_discount_percent': 10}
# {'_shoe_id': UUID('56e01cff-1a96-4d31-84a4-d96c691b9701'), '_shoe_name': 'Puma Suede Classic+', '_brand_name': 'Puma', '_size_number': 43, '_color_name': 'Red', '_discounted_price': 1800000.0, '_promotion_name': 'Quay Trở Lại Trường Học', '_promotion_start_date': '01-09-2024', '_promotion_end_date': '30-09-2024', '_promotion_discount_percent': 10}
# {'_shoe_id': UUID('56a8f1da-ee7b-4698-96b9-69cb5810bdf1'), '_shoe_name': 'Puma Suede Classic+', '_brand_name': 'Puma', '_size_number': 42, '_color_name': 'Yellow', '_discounted_price': 1800000.0, '_promotion_name': 'Quay Trở Lại Trường Học', '_promotion_start_date': '01-09-2024', '_promotion_end_date': '30-09-2024', '_promotion_discount_percent': 10}
# {'_shoe_id': UUID('492bed25-a375-40d3-9913-5ad85a0c9863'), '_shoe_name': 'Puma Suede Classic+', '_brand_name': 'Puma', '_size_number': 43, '_color_name': 'Orange', '_discounted_price': 1800000.0, '_promotion_name': 'Quay Trở Lại Trường Học', '_promotion_start_date': '01-09-2024', '_promotion_end_date': '30-09-2024', '_promotion_discount_percent': 10}
# {'_shoe_id': UUID('34d23ac5-69ed-4aa4-9c6c-3abed669c725'), '_shoe_name': 'Puma Suede Classic+', '_brand_name': 'Puma', '_size_number': 43, '_color_name': 'Blue', '_discounted_price': 1800000.0, '_promotion_name': 'Quay Trở Lại Trường Học', '_promotion_start_date': '01-09-2024', '_promotion_end_date': '30-09-2024', '_promotion_discount_percent': 10}
# {'_shoe_id': UUID('205b42fa-84ad-4d23-a895-df5babe6ae78'), '_shoe_name': 'Puma Suede Classic+', '_brand_name': 'Puma', '_size_number': 43, '_color_name': 'Grey', '_discounted_price': 1800000.0, '_promotion_name': 'Quay Trở Lại Trường Học', '_promotion_start_date': '01-09-2024', '_promotion_end_date': '30-09-2024', '_promotion_discount_percent': 10}
# {'_shoe_id': UUID('ff1aaea7-645c-41ae-a46d-60d052f3c25f'), '_shoe_name': 'Adidas Superstar', '_brand_name': 'Adidas', '_size_number': 43, '_color_name': 'Black', '_discounted_price': 1800000.0, '_promotion_name': 'Quay Trở Lại Trường Học', '_promotion_start_date': '01-09-2024', '_promotion_end_date': '30-09-2024', '_promotion_discount_percent': 10}
# {'_shoe_id': UUID('d9f20257-1120-4883-b89a-1ec1a59a76ee'), '_shoe_name': 'Adidas Superstar', '_brand_name': 'Adidas', '_size_number': 43, '_color_name': 'Red', '_discounted_price': 1800000.0, '_promotion_name': 'Quay Trở Lại Trường Học', '_promotion_start_date': '01-09-2024', '_promotion_end_date': '30-09-2024', '_promotion_discount_percent': 10}
# {'_shoe_id': UUID('c16a19e1-949c-43c2-8849-1b35740d663b'), '_shoe_name': 'Adidas Superstar', '_brand_name': 'Adidas', '_size_number': 43, '_color_name': 'Grey', '_discounted_price': 1800000.0, '_promotion_name': 'Quay Trở Lại Trường Học', '_promotion_start_date': '01-09-2024', '_promotion_end_date': '30-09-2024', '_promotion_discount_percent': 10}
# {'_shoe_id': UUID('b97c2200-439c-4042-b645-0c4831be77dc'), '_shoe_name': 'Adidas Superstar', '_brand_name': 'Adidas', '_size_number': 42, '_color_name': 'Yellow', '_discounted_price': 1800000.0, '_promotion_name': 'Quay Trở Lại Trường Học', '_promotion_start_date': '01-09-2024', '_promotion_end_date': '30-09-2024', '_promotion_discount_percent': 10}
# {'_shoe_id': UUID('aa444127-8080-4ce5-a30d-8b0bae9ab905'), '_shoe_name': 'Adidas Superstar', '_brand_name': 'Adidas', '_size_number': 42, '_color_name': 'Light Blue', '_discounted_price': 1800000.0, '_promotion_name': 'Quay Trở Lại Trường Học', '_promotion_start_date': '01-09-2024', '_promotion_end_date': '30-09-2024', '_promotion_discount_percent': 10}
# {'_shoe_id': UUID('a5fbc823-59e4-4776-bbe4-356c995539e7'), '_shoe_name': 'Adidas Superstar', '_brand_name': 'Adidas', '_size_number': 43, '_color_name': 'Light Blue', '_discounted_price': 1800000.0, '_promotion_name': 'Quay Trở Lại Trường Học', '_promotion_start_date': '01-09-2024', '_promotion_end_date': '30-09-2024', '_promotion_discount_percent': 10}
# {'_shoe_id': UUID('9baf5c0c-ca11-4b74-84ee-387f4b6dd71f'), '_shoe_name': 'Adidas Superstar', '_brand_name': 'Adidas', '_size_number': 42, '_color_name': 'Blue', '_discounted_price': 1800000.0, '_promotion_name': 'Quay Trở Lại Trường Học', '_promotion_start_date': '01-09-2024', '_promotion_end_date': '30-09-2024', '_promotion_discount_percent': 10}
# {'_shoe_id': UUID('88d538e9-d115-42d8-b201-4f3edb822dcb'), '_shoe_name': 'Adidas Superstar', '_brand_name': 'Adidas', '_size_number': 43, '_color_name': 'Yellow', '_discounted_price': 1800000.0, '_promotion_name': 'Quay Trở Lại Trường Học', '_promotion_start_date': '01-09-2024', '_promotion_end_date': '30-09-2024', '_promotion_discount_percent': 10}
# {'_shoe_id': UUID('4b3d47cb-40d6-4270-9d3d-623569e282aa'), '_shoe_name': 'Adidas Superstar', '_brand_name': 'Adidas', '_size_number': 43, '_color_name': 'Orange', '_discounted_price': 1800000.0, '_promotion_name': 'Quay Trở Lại Trường Học', '_promotion_start_date': '01-09-2024', '_promotion_end_date': '30-09-2024', '_promotion_discount_percent': 10}
# {'_shoe_id': UUID('16b403a2-8fa5-4691-897e-d7b1c82ceb3d'), '_shoe_name': 'Adidas Superstar', '_brand_name': 'Adidas', '_size_number': 43, '_color_name': 'Blue', '_discounted_price': 1800000.0, '_promotion_name': 'Quay Trở Lại Trường Học', '_promotion_start_date': '01-09-2024', '_promotion_end_date': '30-09-2024', '_promotion_discount_percent': 10}

# %%
brand_name = [shoe.get_brand_name() for shoe in shoes_kb]
unique_brands = set(brand_name)
print(", ".join(unique_brands))
# Out:
# Reebok, Puma, Nike, Adidas

# %% [markdown]
# ### Mokup of the data and format

# %%
import os
import json


# Hàm tạo phản hồi và ngữ cảnh cho từng câu hỏi
def create_responses_and_context(shoes_kb):
    responses_and_context = {}
    brand_name = [shoe.get_brand_name() for shoe in shoes_kb]
    shoe_name = [shoe.get_shoe_name() for shoe in shoes_kb]
    size_number = [shoe.get_size_number() for shoe in shoes_kb]
    color_name = [shoe.get_color_name() for shoe in shoes_kb]
    # discounted_price = [shoe.get_discounted_price() for shoe in shoes_kb]
    promotion_name = [shoe.get_promotion_name() for shoe in shoes_kb]

    responses_and_context[f"Có tất cả bao nhiêu mặc hàng", "giày"] = {
        "response": f"Tổng số giày hiện có là {len(set(shoe_name))}. Danh sách các giày: {', '.join(map(str,set(shoe_name)))}.",
        "context": f"Thông tin về số lượng giày hiện có.",
    }
    responses_and_context[f"Có tất cả bao nhiêu thương hiệu giày", "thương hiệu"] = {
        "response": f"Tổng số thương hiệu giày hiện có là {len(set(brand_name))}. Danh sách các thương hiệu giày: {', '.join(map(str,set(brand_name)))}.",
        "context": f"Thông tin về số lượng thương hiệu giày hiện có.",
    }
    responses_and_context[f"Có tất cả bao nhiêu màu giày", "màu"] = {
        "response": f"Tổng số màu giày hiện có là {len(set(color_name))}. Danh sách các màu giày: {', '.join(map(str,set(color_name)))}.",
        "context": f"Thông tin về số lượng màu giày hiện có.",
    }
    responses_and_context[f"Có tất cả bao nhiêu kích thước giày", "size"] = {
        "response": f"Tổng số size giày hiện có là {len(set(size_number))}. Danh sách các size giày: {', '.join(map(str, set(size_number)))}.",
        "context": f"Thông tin về số lượng size giày hiện có.",
    }
    responses_and_context[f"Có tất cả bao nhiêu khuyến mãi", "khuyến mãi"] = {
        "response": f"Tổng số khuyến mãi hiện có là {len(set(promotion_name))}. Danh sách các khuyến mãi: {', '.join(map(str,set(promotion_name)))}.",
        "context": f"Thông tin về số lượng khuyến mãi hiện có.",
    }

    for shoe in shoes_kb:
        shoe_name = shoe.get_shoe_name()
        brand_name = shoe.get_brand_name()
        size_number = shoe.get_size_number()
        color_name = shoe.get_color_name()
        discounted_price = shoe.get_discounted_price()
        promotion_name = shoe.get_promotion_name()
        promotion_start_date = shoe.get_promotion_start_date()
        promotion_end_date = shoe.get_promotion_end_date()
        promotion_discount_percent = shoe.get_promotion_discount_percent()

        responses_and_context[f"Có {brand_name} không", f"{brand_name}"] = {
            "response": f"Có, chúng tôi có {shoe_name} từ thương hiệu {brand_name}.",
            "context": f"Thông tin về {shoe_name} từ thương hiệu {brand_name}.",
        }
        responses_and_context[
            f"Bạn có {shoe_name} không",
            f"có {shoe_name} không",
            f"{shoe_name} có không",
            f"{shoe_name}",
        ] = {
            "response": f"Có, chúng tôi có {shoe_name} với màu {color_name} và size {size_number}.",
            "context": f"Thông tin về {shoe_name} với màu {color_name} và size {size_number}.",
        }

        responses_and_context[
            f"Giày {shoe_name} màu {color_name} có đẹp không",
            f"{shoe_name} màu {color_name} đẹp không",
            f"{shoe_name} màu {color_name}",
        ] = {
            "response": f"Có, giày {shoe_name} màu {color_name} là một trong những màu được ưa chuộng.",
            "context": f"Thông tin về giày {shoe_name} màu {color_name}.",
        }

        responses_and_context[
            f"giày {shoe_name} giá bao nhiêu",
            f"{shoe_name} giá bao nhiêu",
            f"{shoe_name} giá",
        ] = {
            "response": f"Giày {shoe_name} giá {discounted_price} VNĐ.",
            "context": f"Thông tin về giày {shoe_name} giá {discounted_price} VNĐ.",
        }

        responses_and_context[
            f"khuyến mãi",
            f"khuyến mãi {promotion_name}" f"{promotion_name}",
            f"{promotion_name}",
        ] = {
            "response": f"khuyến mãi {promotion_name} bắt đầu từ ngày {promotion_start_date}.",
            "context": f"thông tin về khuyến mãi {promotion_name} bắt đầu từ ngày {promotion_start_date} kết thúc vào ngày {promotion_end_date} với giá giảm {promotion_discount_percent}%.",
        }

    return responses_and_context


# Tải dữ liệu từ cơ sở dữ liệu
shoes_kb = crud_knowledge_base.get_default_kn_chatbot(db=Session(engine), limit=25)

# Tạo phản hồi và ngữ cảnh cho từng câu hỏi
responses_and_context = create_responses_and_context(shoes_kb)

# Tạo danh sách intents từ phản hồi và ngữ cảnh đã tạo
intents = [
    {
        "tag": "greeting",
        "patterns": [
            "Xin chào",
            ".",
            "Chào shop",
            "Này",
            "Hi",
            "Xin chào",
            "Hello",
            "Alo",
        ],
        "responses": ["Xin chào, Shop có thể giúp gì cho bạn"],
        "context": [""],
    },
    {
        "tag": "goodbye",
        "patterns": [
            "Hẹn gặp lại",
            "Tạm biệt",
            "Bye",
            "Rất vui được trò chuyện với bạn, tạm biệt",
        ],
        "responses": ["Tạm biệt! Cảm ơn bạn hẹn gặp lại."],
        "context": [""],
    },
    {
        "tag": "thanks",
        "patterns": [
            "Thanks",
            "Cảm ơn",
            "Cảm ơn shop ạ",
            "Tuyệt vời, cảm ơn",
            "Cảm ơn vì đã giúp tôi",
        ],
        "responses": ["Cảm ơn bạn! Hẹn sớm gặp lại bạn"],
        "context": [""],
    },
    {
        "tag": "noanswer",
        "patterns": [],
        "responses": ["Xin vui lòng cho tôi thêm thông tin"],
        "context": [""],
    },
    {
        "tag": "options",
        "patterns": [
            "Shop có thể giúp gì",
            "Bạn có thể giúp tôi cái gì",
            "Hỗ trợ gì được cung cấp",
        ],
        "responses": [
            "Tôi có thể giúp bạn tư vấn và giới thiệu các sản phẩm mà shop có ạ!"
        ],
        "context": [""],
    },
]
for question, data in responses_and_context.items():

    intents.append(
        {
            "tag": question[0].lower().replace(" ", "_"),
            "patterns": [question],
            "responses": [data["response"]],
            "context": [data["context"]],
        }
    )

# Lưu dữ liệu đã cập nhật vào tệp intents.json
script_dir = os.getcwd()
intents_file_path = os.path.join(script_dir, "intents.json")

with open(intents_file_path, "w") as outfile:
    json.dump({"intents": intents}, outfile, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Save the updated data to the intents.json file

# %%
script_dir = os.getcwd()
intents_file_path = os.path.join(script_dir, "intents.json")

with open(intents_file_path, "w") as outfile:
    json.dump({"intents": intents}, outfile, ensure_ascii=False, indent=4)
