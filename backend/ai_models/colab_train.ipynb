# %%
import nltk

nltk.download("punkt")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# import thư viện
import nltk
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random

# đọc file json các mẫu câu hỏi và câu trả lời
words = []
classes = []
documents = []
ignore_words = ["?", "!"]

data_file = open("/content/drive/MyDrive/code/Chatbot/intents.json").read()
intents = json.loads(data_file)

# # Tiền xử lý dữ liệu
# for intent in intents["intents"]:
#     for pattern in intent["patterns"]:

#         # tokenize each word
#         w = nltk.word_tokenize(pattern)
#         words.extend(w)
#         # add documents in the corpus
#         documents.append((w, intent["tag"]))

#         # add to our classes list
#         if intent["tag"] not in classes:
#             classes.append(intent["tag"])
# Tiền xử lý dữ liệu
for intent in intents["intents"]:
    for pattern in intent["patterns"]:
        # pattern is a list, so we need to join it into a string
        pattern_str = ' '.join(pattern) # Join the list of strings into a single string with spaces in between
        # tokenize each word
        w = nltk.word_tokenize(pattern_str)
        words.extend(w)
        # add documents in the corpus
        documents.append((w, intent["tag"]))

        # add to our classes list
        if intent["tag"] not in classes:
            classes.append(intent["tag"])

# Các từ được lemmatized và chuyển đổi thành chữ thường, sau đó loại bỏ các từ không quan trọng như dấu chấm hỏi và dấu chấm than.
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print(len(documents), "documents")
# classes = intents
print(len(classes), "classes", classes)
# words = all words, vocabulary
print(len(words), "unique lemmatized words", words)


pickle.dump(words, open("/content/drive/MyDrive/code/Chatbot/words.pkl", "wb"))
pickle.dump(classes, open("/content/drive/MyDrive/code/Chatbot/classes.pkl", "wb"))


# Tạo dữ liệu huấn luyện
# tạo training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# tập huấn luyện, túi từ cho mỗi câu
for doc in documents:
    # Khởi tạo
    bag = []
    # danh sách các từ được mã hóa cho mẫu
    pattern_words = doc[0]
    # bổ nghĩa hóa từng từ - tạo từ cơ sở, nhằm thể hiện các từ liên quan
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # tạo mảng từ của chúng ta bằng 1, nếu tìm thấy từ khớp trong mẫu hiện tại
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # đầu ra là '0' cho mỗi thẻ và '1' cho thẻ hiện tại (cho mỗi mẫu)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])

# xáo trộn dữ liện huấn luyện và biến đổi chúng thành np.array
random.shuffle(training)

# Tách các tính năng (X) và nhãn (Y) khỏi dữ liệu huấn luyện
train_x = np.array([x[0] for x in training])  # X - patterns
train_y = np.array([x[1] for x in training])  # Y - intents

print("Training data created")


# Tạo model - 3 layers.  128 neurons, 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation="softmax"))

# Compile model. Giảm độ dốc ngẫu nhiên với độ dốc tăng tốc Nesterov cho kết quả tốt cho mô hình này
sgd = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model.compile(loss="categorical_crossentropy", optimizer=sgd, metrics=["accuracy"])

# lưu mmodel
hist = model.fit(
    np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1
)
model.save("/content/drive/MyDrive/code/Chatbot/chatbot_model.h5", hist)

print("model created and saved")
# Out:
# 67 documents
# 14/14 [==============================] - 0s 7ms/step - loss: 1.0702 - accuracy: 0.6418
# Epoch 66/200
# 14/14 [==============================] - 0s 8ms/step - loss: 0.8704 - accuracy: 0.7015
# Epoch 67/200
# 14/14 [==============================] - 0s 10ms/step - loss: 1.1533 - accuracy: 0.6269
# Epoch 68/200
# 14/14 [==============================] - 0s 11ms/step - loss: 1.0206 - accuracy: 0.6418
# Epoch 69/200
# 14/14 [==============================] - 0s 8ms/step - loss: 0.7401 - accuracy: 0.7761
# Epoch 70/200
# 14/14 [==============================] - 0s 8ms/step - loss: 1.0393 - accuracy: 0.6716
# Epoch 71/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.8794 - accuracy: 0.6716
# Epoch 72/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.9394 - accuracy: 0.7313
# Epoch 73/200
# 14/14 [==============================] - 0s 8ms/step - loss: 0.8332 - accuracy: 0.7164
# Epoch 74/200
# 14/14 [==============================] - 0s 8ms/step - loss: 0.8637 - accuracy: 0.7313
# Epoch 75/200
# 14/14 [==============================] - 0s 6ms/step - loss: 1.1340 - accuracy: 0.6269
# Epoch 76/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.9669 - accuracy: 0.7015
# Epoch 77/200
# 14/14 [==============================] - 0s 6ms/step - loss: 1.0191 - accuracy: 0.6119
# Epoch 78/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.9353 - accuracy: 0.6716
# Epoch 79/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6746 - accuracy: 0.7612
# Epoch 80/200
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6533 - accuracy: 0.8060
# Epoch 81/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.8359 - accuracy: 0.7164
# Epoch 82/200
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6094 - accuracy: 0.8209
# Epoch 83/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.7618 - accuracy: 0.7313
# Epoch 84/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.7852 - accuracy: 0.7015
# Epoch 85/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.5739 - accuracy: 0.8060
# Epoch 86/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4836 - accuracy: 0.8806
# Epoch 87/200
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6536 - accuracy: 0.7612
# Epoch 88/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.7241 - accuracy: 0.7612
# Epoch 89/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.9426 - accuracy: 0.6716
# Epoch 90/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.9599 - accuracy: 0.7612
# Epoch 91/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.7581 - accuracy: 0.7313
# Epoch 92/200
# 14/14 [==============================] - 0s 8ms/step - loss: 0.7787 - accuracy: 0.7761
# Epoch 93/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6720 - accuracy: 0.7761
# Epoch 94/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.7436 - accuracy: 0.7313
# Epoch 95/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6212 - accuracy: 0.8209
# Epoch 96/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.5543 - accuracy: 0.8358
# Epoch 97/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.6680 - accuracy: 0.7612
# Epoch 98/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.8198 - accuracy: 0.7612
# Epoch 99/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5168 - accuracy: 0.8358
# Epoch 100/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.7993 - accuracy: 0.6866
# Epoch 101/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.6628 - accuracy: 0.7910
# Epoch 102/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.5159 - accuracy: 0.7761
# Epoch 103/200
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5450 - accuracy: 0.8358
# Epoch 104/200
# 14/14 [==============================] - 0s 11ms/step - loss: 0.7140 - accuracy: 0.7761
# Epoch 105/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.8688 - accuracy: 0.7313
# Epoch 106/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.8043 - accuracy: 0.7164
# Epoch 107/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6072 - accuracy: 0.8209
# Epoch 108/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.5859 - accuracy: 0.8060
# Epoch 109/200
# 14/14 [==============================] - 0s 12ms/step - loss: 0.7790 - accuracy: 0.7164
# Epoch 110/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.4953 - accuracy: 0.8657
# Epoch 111/200
# 14/14 [==============================] - 0s 12ms/step - loss: 0.5975 - accuracy: 0.7761
# Epoch 112/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.5928 - accuracy: 0.7761
# Epoch 113/200
# 14/14 [==============================] - 0s 8ms/step - loss: 0.7631 - accuracy: 0.7463
# Epoch 114/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.5922 - accuracy: 0.7761
# Epoch 115/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.6254 - accuracy: 0.7761
# Epoch 116/200
# 14/14 [==============================] - 0s 11ms/step - loss: 0.7209 - accuracy: 0.7761
# Epoch 117/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6020 - accuracy: 0.7910
# Epoch 118/200
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6991 - accuracy: 0.7612
# Epoch 119/200
# 14/14 [==============================] - 0s 8ms/step - loss: 0.7672 - accuracy: 0.7015
# Epoch 120/200
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6168 - accuracy: 0.7612
# Epoch 121/200
# 14/14 [==============================] - 0s 8ms/step - loss: 0.8433 - accuracy: 0.7761
# Epoch 122/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.7331 - accuracy: 0.7612
# Epoch 123/200
# 14/14 [==============================] - 0s 11ms/step - loss: 0.6066 - accuracy: 0.8060
# Epoch 124/200
# 14/14 [==============================] - 0s 19ms/step - loss: 0.8566 - accuracy: 0.6716
# Epoch 125/200
# 14/14 [==============================] - 0s 11ms/step - loss: 0.5019 - accuracy: 0.8358
# Epoch 126/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6558 - accuracy: 0.8060
# Epoch 127/200
# 14/14 [==============================] - 0s 8ms/step - loss: 0.4763 - accuracy: 0.8507
# Epoch 128/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.7705 - accuracy: 0.7612
# Epoch 129/200
# 14/14 [==============================] - 0s 12ms/step - loss: 0.5779 - accuracy: 0.8060
# Epoch 130/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.5468 - accuracy: 0.7612
# Epoch 131/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.5197 - accuracy: 0.8060
# Epoch 132/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.7568 - accuracy: 0.7612
# Epoch 133/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.5546 - accuracy: 0.8507
# Epoch 134/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6412 - accuracy: 0.8507
# Epoch 135/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4447 - accuracy: 0.8209
# Epoch 136/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.6019 - accuracy: 0.7612
# Epoch 137/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6226 - accuracy: 0.7463
# Epoch 138/200
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5168 - accuracy: 0.8060
# Epoch 139/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6259 - accuracy: 0.8060
# Epoch 140/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6014 - accuracy: 0.7910
# Epoch 141/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.5874 - accuracy: 0.8209
# Epoch 142/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.7384 - accuracy: 0.8060
# Epoch 143/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4920 - accuracy: 0.8209
# Epoch 144/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4671 - accuracy: 0.8507
# Epoch 145/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.5036 - accuracy: 0.8507
# Epoch 146/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4668 - accuracy: 0.8209
# Epoch 147/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4493 - accuracy: 0.8507
# Epoch 148/200
# 14/14 [==============================] - 0s 14ms/step - loss: 0.2814 - accuracy: 0.9104
# Epoch 149/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6137 - accuracy: 0.8060
# Epoch 150/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.4676 - accuracy: 0.8507
# Epoch 151/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.6883 - accuracy: 0.8209
# Epoch 152/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5281 - accuracy: 0.8507
# Epoch 153/200
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3867 - accuracy: 0.8209
# Epoch 154/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.7125 - accuracy: 0.7910
# Epoch 155/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4894 - accuracy: 0.8507
# Epoch 156/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.5286 - accuracy: 0.8358
# Epoch 157/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6231 - accuracy: 0.7761
# Epoch 158/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.7009 - accuracy: 0.7761
# Epoch 159/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6187 - accuracy: 0.7761
# Epoch 160/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.6618 - accuracy: 0.7910
# Epoch 161/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.5365 - accuracy: 0.8060
# Epoch 162/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4768 - accuracy: 0.7910
# Epoch 163/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.3388 - accuracy: 0.9403
# Epoch 164/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.4380 - accuracy: 0.8806
# Epoch 165/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3758 - accuracy: 0.8507
# Epoch 166/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3722 - accuracy: 0.8507
# Epoch 167/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2998 - accuracy: 0.9104
# Epoch 168/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.7154 - accuracy: 0.7313
# Epoch 169/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.6228 - accuracy: 0.7910
# Epoch 170/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.6989 - accuracy: 0.7612
# Epoch 171/200
# 14/14 [==============================] - 0s 11ms/step - loss: 0.2921 - accuracy: 0.8955
# Epoch 172/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.4678 - accuracy: 0.8060
# Epoch 173/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3468 - accuracy: 0.8657
# Epoch 174/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.4259 - accuracy: 0.8507
# Epoch 175/200
# 14/14 [==============================] - 0s 11ms/step - loss: 0.4447 - accuracy: 0.8209
# Epoch 176/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.5308 - accuracy: 0.8209
# Epoch 177/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6073 - accuracy: 0.7910
# Epoch 178/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4424 - accuracy: 0.8507
# Epoch 179/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.5912 - accuracy: 0.8209
# Epoch 180/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4767 - accuracy: 0.8507
# Epoch 181/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4351 - accuracy: 0.8806
# Epoch 182/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3814 - accuracy: 0.8507
# Epoch 183/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.4332 - accuracy: 0.8358
# Epoch 184/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3361 - accuracy: 0.8955
# Epoch 185/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3493 - accuracy: 0.8657
# Epoch 186/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.3147 - accuracy: 0.8955
# Epoch 187/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.4575 - accuracy: 0.8209
# Epoch 188/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5263 - accuracy: 0.7761
# Epoch 189/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2427 - accuracy: 0.9254
# Epoch 190/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4180 - accuracy: 0.8806
# Epoch 191/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2718 - accuracy: 0.9552
# Epoch 192/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5740 - accuracy: 0.7910
# Epoch 193/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5822 - accuracy: 0.8209
# Epoch 194/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3930 - accuracy: 0.8657
# Epoch 195/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5159 - accuracy: 0.7910
# Epoch 196/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4426 - accuracy: 0.8657
# Epoch 197/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5094 - accuracy: 0.8358
# Epoch 198/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4662 - accuracy: 0.8358
# Epoch 199/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5487 - accuracy: 0.8358
# Epoch 200/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3305 - accuracy: 0.8955
# model created and saved

# %% [markdown]
# # Test

# %%
# Load mô hình và các dữ liệu cần thiết từ các tệp đã lưu trữ trước đó
model = load_model('/content/drive/MyDrive/code/Chatbot/chatbot_model.h5')
intents = json.loads(open('/content/drive/MyDrive/code/Chatbot/intents.json').read())
words = pickle.load(open('/content/drive/MyDrive/code/Chatbot/words.pkl','rb'))
classes = pickle.load(open('/content/drive/MyDrive/code/Chatbot/classes.pkl','rb'))

# Định nghĩa hàm để làm sạch câu nhập từ người dùng
lemmatizer = WordNetLemmatizer()

def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# Định nghĩa hàm bow (bag of words) để chuyển đổi câu nhập thành một vector các từ
def bow(sentence, words, show_details=True):
    sentence_words = clean_up_sentence(sentence)
    bag = [0] * len(words)
    for s in sentence_words:
        for i, w in enumerate(words):
            if w == s:
                bag[i] = 1
                if show_details:
                    print("found in bag: %s" % w)
    return np.array(bag)

# Định nghĩa hàm predict_class để dự đoán nhãn (intent) của câu nhập:
def predict_class(sentence, model):
    p = bow(sentence, words, show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i, r] for i, r in enumerate(res) if r > ERROR_THRESHOLD]
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

def getResponse(ints, intents_json):
    tag = ints[0]["intent"]
    print(tag)
    list_of_intents = intents_json["intents"]
    for i in list_of_intents:
        if i["tag"] == tag:
            result = random.choice(i["responses"])
            break
    return result

def chatbot_response(msg):
    ints = predict_class(msg, model)
    if ints:
        res = getResponse(ints, intents)
        return res
    else:
        return "Xin lỗi, tôi không hiểu câu của bạn. Vui lòng thử lại."

# Tạo vòng lặp vô hạn để cho phép người dùng tương tác với chatbot
while True:
    user_input = input("You: ")
    if user_input.lower() == 'quit':
        break
    response = chatbot_response(user_input)
    print("Bot:", response)
# Out:
# You: Có tất cả bao nhiêu mặc hàng
# 1/1 [==============================] - 0s 62ms/step
# có_tất_cả_bao_nhiêu_mặc_hàng
# Bot: Tổng số giày hiện có là 4. Danh sách các giày: Nike Air Max 90 Essential, Puma Suede Classic+, Adidas Superstar, Reebok Classic.
# You: Có tất cả bao nhiêu thương hiệu giày
# 1/1 [==============================] - 0s 20ms/step
# có_tất_cả_bao_nhiêu_thương_hiệu_giày
# Bot: Tổng số thương hiệu giày hiện có là 4. Danh sách các thương hiệu giày: Reebok, Puma, Nike, Adidas.
# You: Có tất cả bao nhiêu màu giày
# 1/1 [==============================] - 0s 20ms/step
# có_tất_cả_bao_nhiêu_màu_giày
# Bot: Tổng số màu giày hiện có là 7. Danh sách các màu giày: Grey, Black, Red, Light Blue, Blue, Yellow, Orange.
# You: Có tất cả bao nhiêu kích thước giày
# 1/1 [==============================] - 0s 20ms/step
# có_tất_cả_bao_nhiêu_kích_thước_giày
# Bot: Tổng số size giày hiện có là 2. Danh sách các size giày: 42, 43.
# You: Có tất cả bao nhiêu khuyến mãi
# 1/1 [==============================] - 0s 32ms/step
# có_tất_cả_bao_nhiêu_khuyến_mãi
# Bot: Tổng số khuyến mãi hiện có là 2. Danh sách các khuyến mãi: Mùa Hè Sale cùng Sole Mate AI, Quay Trở Lại Trường Học.
# You: Nike
# 1/1 [==============================] - 0s 21ms/step
# greeting
# Bot: Xin chào, Shop có thể giúp gì cho bạn
# You: Có Nike không
# 1/1 [==============================] - 0s 20ms/step
# có_nike_không
# Bot: Có, chúng tôi có Nike Air Max 90 Essential từ thương hiệu Nike.
# You: Có Puma không
# 1/1 [==============================] - 0s 32ms/step
# có_puma_không
# Bot: Có, chúng tôi có Puma Suede Classic+ từ thương hiệu Puma.
# You: Có adidas không
# 1/1 [==============================] - 0s 21ms/step
# có_adidas_không
# Bot: Có, chúng tôi có Adidas Superstar từ thương hiệu Adidas.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-3caffdf304fd> in <cell line: 58>()
#      57 # Tạo vòng lặp vô hạn để cho phép người dùng tương tác với chatbot
#      58 while True:
# ---> 59     user_input = input("You: ")
#      60     if user_input.lower() == 'quit':
#      61         break
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
