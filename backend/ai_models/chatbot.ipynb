# %%
import nltk

nltk.download("punkt")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# import thư viện
import nltk
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random

# đọc file json các mẫu câu hỏi và câu trả lời
words = []
classes = []
documents = []
ignore_words = ["?", "!"]

data_file = open("/content/drive/MyDrive/code/Chatbot/intents.json").read()
intents = json.loads(data_file)

# Tiền xử lý dữ liệu
for intent in intents["intents"]:
    for pattern in intent["patterns"]:

        # tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        # add documents in the corpus
        documents.append((w, intent["tag"]))

        # add to our classes list
        if intent["tag"] not in classes:
            classes.append(intent["tag"])

# Các từ được lemmatized và chuyển đổi thành chữ thường, sau đó loại bỏ các từ không quan trọng như dấu chấm hỏi và dấu chấm than.
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print(len(documents), "documents")
# classes = intents
print(len(classes), "classes", classes)
# words = all words, vocabulary
print(len(words), "unique lemmatized words", words)


pickle.dump(words, open("/content/drive/MyDrive/code/Chatbot/words.pkl", "wb"))
pickle.dump(classes, open("/content/drive/MyDrive/code/Chatbot/classes.pkl", "wb"))


# Tạo dữ liệu huấn luyện
# tạo training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# tập huấn luyện, túi từ cho mỗi câu
for doc in documents:
    # Khởi tạo
    bag = []
    # danh sách các từ được mã hóa cho mẫu
    pattern_words = doc[0]
    # bổ nghĩa hóa từng từ - tạo từ cơ sở, nhằm thể hiện các từ liên quan
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # tạo mảng từ của chúng ta bằng 1, nếu tìm thấy từ khớp trong mẫu hiện tại
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # đầu ra là '0' cho mỗi thẻ và '1' cho thẻ hiện tại (cho mỗi mẫu)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])

# xáo trộn dữ liện huấn luyện và biến đổi chúng thành np.array
random.shuffle(training)

# Tách các tính năng (X) và nhãn (Y) khỏi dữ liệu huấn luyện
train_x = np.array([x[0] for x in training])  # X - patterns
train_y = np.array([x[1] for x in training])  # Y - intents

print("Training data created")


# Tạo model - 3 layers.  128 neurons, 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation="softmax"))

# Compile model. Giảm độ dốc ngẫu nhiên với độ dốc tăng tốc Nesterov cho kết quả tốt cho mô hình này
sgd = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model.compile(loss="categorical_crossentropy", optimizer=sgd, metrics=["accuracy"])

# lưu mmodel
hist = model.fit(
    np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1
)
model.save("/content/drive/MyDrive/code/Chatbot/chatbot_model.h5", hist)

print("model created and saved")
# Out:
# 24 documents
# 5 classes ['goodbye', 'greeting', 'options', 'product', 'thanks']
# 60 unique lemmatized words [',', '.', 'alo', 'biệt', 'bye', 'bán', 'bên', 'bạn', 'cho', 'chuyện', 'chào', 'có', 'cung', 'các', 'có', 'cảm', 'cấp', 'của', 'giày', 'giúp', 'giới', 'gì', 'gặp', 'hello', 'hi', 'hot', 'hẹn', 'hỗ', 'lại', 'mình', 'một', 'nhiều', 'nhất', 'này', 'phẩm', 'rất', 'shop', 'sản', 'số', 'thanks', 'thiệu', 'thể', 'trong', 'trò', 'trợ', 'tuyệt', 'tôi', 'tạm', 'vui', 'về', 'vì', 'với', 'vời', 'xin', 'đã', 'đôi', 'được', 'đẹp', 'ơn', 'ạ']
# Training data created
# Epoch 1/200
# 5/5 [==============================] - 1s 5ms/step - loss: 1.7168 - accuracy: 0.1250
# Epoch 2/200
# 5/5 [==============================] - 0s 4ms/step - loss: 1.6351 - accuracy: 0.3333
# Epoch 3/200
# 5/5 [==============================] - 0s 3ms/step - loss: 1.5925 - accuracy: 0.5000
# Epoch 4/200
# 5/5 [==============================] - 0s 3ms/step - loss: 1.5517 - accuracy: 0.3333
# Epoch 5/200
# 5/5 [==============================] - 0s 3ms/step - loss: 1.4011 - accuracy: 0.5417
# Epoch 6/200
# 5/5 [==============================] - 0s 3ms/step - loss: 1.3894 - accuracy: 0.4583
# Epoch 7/200
# 5/5 [==============================] - 0s 3ms/step - loss: 1.3479 - accuracy: 0.6667
# Epoch 8/200
# 5/5 [==============================] - 0s 3ms/step - loss: 1.1324 - accuracy: 0.8333
# Epoch 9/200
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2377 - accuracy: 0.5833
# Epoch 10/200
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0724 - accuracy: 0.7500
# Epoch 11/200
# 5/5 [==============================] - 0s 4ms/step - loss: 1.1163 - accuracy: 0.6667
# Epoch 12/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.9139 - accuracy: 0.8333
# Epoch 13/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8575 - accuracy: 0.9583
# Epoch 14/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8539 - accuracy: 0.7500
# Epoch 15/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6120 - accuracy: 0.8750
# Epoch 16/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.7432 - accuracy: 0.7917
# Epoch 17/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5260 - accuracy: 0.9167
# Epoch 18/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4547 - accuracy: 0.9583
# Epoch 19/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4598 - accuracy: 0.9167
# Epoch 20/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4607 - accuracy: 0.9167
# Epoch 21/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3784 - accuracy: 0.9167
# Epoch 22/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4726 - accuracy: 0.9167
# Epoch 23/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3361 - accuracy: 0.9583
# Epoch 24/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3013 - accuracy: 1.0000
# Epoch 25/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2576 - accuracy: 0.9583
# Epoch 26/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2808 - accuracy: 0.9583
# Epoch 27/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3428 - accuracy: 0.9167
# Epoch 28/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2969 - accuracy: 0.9583
# Epoch 29/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2781 - accuracy: 0.9583
# Epoch 30/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0835 - accuracy: 1.0000
# Epoch 31/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2262 - accuracy: 0.9583
# Epoch 32/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1702 - accuracy: 1.0000
# Epoch 33/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1557 - accuracy: 1.0000
# Epoch 34/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2580 - accuracy: 0.9583
# Epoch 35/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1209 - accuracy: 1.0000
# Epoch 36/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1586 - accuracy: 0.9583
# Epoch 37/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1168 - accuracy: 1.0000
# Epoch 38/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1372 - accuracy: 0.9583
# Epoch 39/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1246 - accuracy: 0.9583
# Epoch 40/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1163 - accuracy: 1.0000
# Epoch 41/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1457 - accuracy: 1.0000
# Epoch 42/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1313 - accuracy: 0.9583
# Epoch 43/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1245 - accuracy: 0.9583
# Epoch 44/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1281 - accuracy: 0.9583
# Epoch 45/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0578 - accuracy: 1.0000
# Epoch 46/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1512 - accuracy: 0.9167
# Epoch 47/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1067 - accuracy: 1.0000
# Epoch 48/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0667 - accuracy: 1.0000
# Epoch 49/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0761 - accuracy: 1.0000
# Epoch 50/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0945 - accuracy: 1.0000
# Epoch 51/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1757 - accuracy: 0.9583
# Epoch 52/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1039 - accuracy: 0.9583
# Epoch 53/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0478 - accuracy: 1.0000
# Epoch 54/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0781 - accuracy: 1.0000
# Epoch 55/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0723 - accuracy: 0.9583
# Epoch 56/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0503 - accuracy: 1.0000
# Epoch 57/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1304 - accuracy: 0.9583
# Epoch 58/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0277 - accuracy: 1.0000
# Epoch 59/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0336 - accuracy: 1.0000
# Epoch 60/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0528 - accuracy: 1.0000
# Epoch 61/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 62/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0768 - accuracy: 1.0000
# Epoch 63/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0287 - accuracy: 1.0000
# Epoch 64/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0260 - accuracy: 1.0000
# Epoch 65/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0304 - accuracy: 1.0000
# Epoch 66/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0970 - accuracy: 1.0000
# Epoch 67/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0291 - accuracy: 1.0000
# Epoch 68/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0743 - accuracy: 1.0000
# Epoch 69/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0394 - accuracy: 1.0000
# Epoch 70/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0626 - accuracy: 1.0000
# Epoch 71/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0244 - accuracy: 1.0000
# Epoch 72/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 73/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0425 - accuracy: 1.0000
# Epoch 74/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1281 - accuracy: 0.9583
# Epoch 75/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 76/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 77/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0293 - accuracy: 1.0000
# Epoch 78/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0501 - accuracy: 0.9583
# Epoch 79/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 80/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0429 - accuracy: 1.0000
# Epoch 81/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0189 - accuracy: 1.0000
# Epoch 82/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1309 - accuracy: 0.9583
# Epoch 83/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0462 - accuracy: 1.0000
# Epoch 84/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0315 - accuracy: 1.0000
# Epoch 85/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0271 - accuracy: 1.0000
# Epoch 86/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0250 - accuracy: 1.0000
# Epoch 87/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0263 - accuracy: 1.0000
# Epoch 88/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0472 - accuracy: 1.0000
# Epoch 89/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0974 - accuracy: 1.0000
# Epoch 90/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0218 - accuracy: 1.0000
# Epoch 91/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 92/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0381 - accuracy: 1.0000
# Epoch 93/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0263 - accuracy: 1.0000
# Epoch 94/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 95/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0288 - accuracy: 1.0000
# Epoch 96/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 97/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0463 - accuracy: 1.0000
# Epoch 98/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0243 - accuracy: 1.0000
# Epoch 99/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0563 - accuracy: 1.0000
# Epoch 100/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0387 - accuracy: 1.0000
# Epoch 101/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0270 - accuracy: 1.0000
# Epoch 102/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 103/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 104/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 105/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0287 - accuracy: 1.0000
# Epoch 106/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0297 - accuracy: 1.0000
# Epoch 107/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0299 - accuracy: 1.0000
# Epoch 108/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0224 - accuracy: 1.0000
# Epoch 109/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0276 - accuracy: 1.0000
# Epoch 110/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 111/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 112/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 113/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0289 - accuracy: 1.0000
# Epoch 114/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 115/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 116/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 117/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 118/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 119/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 120/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 121/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0537 - accuracy: 1.0000
# Epoch 122/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1102 - accuracy: 0.9583
# Epoch 123/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 124/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0189 - accuracy: 1.0000
# Epoch 125/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 126/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0291 - accuracy: 1.0000
# Epoch 127/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 128/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 129/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0397 - accuracy: 1.0000
# Epoch 130/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 131/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0604 - accuracy: 1.0000
# Epoch 132/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0452 - accuracy: 1.0000
# Epoch 133/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 134/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0536 - accuracy: 1.0000
# Epoch 135/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0641 - accuracy: 0.9583
# Epoch 136/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 137/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 138/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 139/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 140/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0218 - accuracy: 1.0000
# Epoch 141/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0380 - accuracy: 1.0000
# Epoch 142/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 143/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0495 - accuracy: 1.0000
# Epoch 144/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 145/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0243 - accuracy: 1.0000
# Epoch 146/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 147/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0624 - accuracy: 0.9583
# Epoch 148/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 149/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 150/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 151/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 152/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 153/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 154/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0398 - accuracy: 1.0000
# Epoch 155/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0189 - accuracy: 1.0000
# Epoch 156/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 157/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 158/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 159/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0241 - accuracy: 1.0000
# Epoch 160/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 161/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 162/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 163/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 164/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 165/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 166/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 167/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 168/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0250 - accuracy: 1.0000
# Epoch 169/200
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0403 - accuracy: 1.0000
# Epoch 170/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 171/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 172/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0570 - accuracy: 0.9583
# Epoch 173/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 174/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 175/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 176/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 177/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 178/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 179/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 180/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 181/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 182/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0198 - accuracy: 1.0000
# Epoch 183/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 184/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 185/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0275 - accuracy: 1.0000
# Epoch 186/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 187/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 188/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 189/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 190/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0530 - accuracy: 1.0000
# Epoch 191/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 192/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 193/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 194/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 195/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 196/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 197/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 198/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0225 - accuracy: 1.0000
# Epoch 199/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 200/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0031 - accuracy: 1.0000
# model created and saved
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import nltk
from nltk.stem import WordNetLemmatizer
import pickle
import numpy as np

from tensorflow.keras.models import load_model
import json
import random

import os

script_dir = os.getcwd()

model_file_path = os.path.join(script_dir, "chatbot_model.h5")
intents_file_path = os.path.join(script_dir, "intents.json")
words_file_path = os.path.join(script_dir, "words.pkl")
classes_file_path = os.path.join(script_dir, "classes.pkl")


# Load mô hình và các dữ liệu cần thiết từ các tệp đã lưu trữ trước đó
# model = load_model('/content/drive/MyDrive/code/Chatbot/chatbot_model.h5')
# intents = json.loads(open('/content/drive/MyDrive/code/Chatbot/intents.json').read())
# words = pickle.load(open('/content/drive/MyDrive/code/Chatbot/words.pkl','rb'))
# classes = pickle.load(open('/content/drive/MyDrive/code/Chatbot/classes.pkl','rb'))

model = load_model(model_file_path)
intents = json.loads(open(intents_file_path).read())
words = pickle.load(open(words_file_path, "rb"))
classes = pickle.load(open(classes_file_path, "rb"))


# Định nghĩa hàm để làm sạch câu nhập từ người dùng
lemmatizer = WordNetLemmatizer()


def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words


# Định nghĩa hàm bow (bag of words) để chuyển đổi câu nhập thành một vector các từ
def bow(sentence, words, show_details=True):
    sentence_words = clean_up_sentence(sentence)
    bag = [0] * len(words)
    for s in sentence_words:
        for i, w in enumerate(words):
            if w == s:
                bag[i] = 1
                if show_details:
                    print("found in bag: %s" % w)
    return np.array(bag)


# Định nghĩa hàm predict_class để dự đoán nhãn (intent) của câu nhập:
def predict_class(sentence, model):
    p = bow(sentence, words, show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i, r] for i, r in enumerate(res) if r > ERROR_THRESHOLD]
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list


# Định nghĩa hàm getResponse để lấy câu trả lời từ dữ liệu intents dựa trên nhãn được dự đoán:
def getResponse(ints, intents_json):
    tag = ints[0]["intent"]
    list_of_intents = intents_json["intents"]
    for i in list_of_intents:
        if i["tag"] == tag:
            result = random.choice(i["responses"])
            break
    return result


def chatbot_response(msg):
    ints = predict_class(msg, model)
    res = getResponse(ints, intents)
    return res


# # Tạo vòng lặp vô hạn để cho phép người dùng tương tác với chatbot
# while True:
#     user_input = input("You: ")
#     if user_input.lower() == 'quit':
#         break
#     response = chatbot_response(user_input)
#     print("Bot:", response)

# Danh sách các câu hỏi được xác định trước
predefined_questions = [
    "Xin chào",
    "Các đôi giày có trong shop",
]

# Duyệt qua danh sách các câu hỏi và in ra câu trả lời từ chatbot
for question in predefined_questions:
    print("You:", question)
    response = chatbot_response(question)
    print("Bot:", response)
# Out:
# c:\Users\dongu\miniconda3\envs\sole_mate_ai\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# You: Xin chào
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# Bot: Xin chào, Shop có thể giúp gì cho bạn?
# You: Các đôi giày có trong shop
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Bot: Sau đây là một số sản phẩm shop gợi ý cho bạn: /n Giày thể thao nam Nike Air Max 90 Essential. /n Giày thể thao nữ Reebok Classic. /n Giày thể thao nam Puma Suede Classic+. /n Giày thể thao nam Adidas Superstar.
